# %% [markdown]
# # Exploting a Pandas Data Frame

# %%
#Import general python packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Chek version of pakages
print ("numpy version:", np.__version__)
print ("panda version:", pd.__version__)
# Out:
# numpy version: 1.21.1
# panda version: 1.3.1

# %% [markdown]
# # Step 1: Load the dataset as a Pandas data frame.
# ### Read the 'Video_Games_Sales_as_at_22_Dec_2016.csv' file

# %%
#Read "Video_Games_Sales_as_at_22_Dec_2016.csv" file 
df=pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Step 2: Display the first ten rows of data.

# %%
# Display the first 10 rows
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %% [markdown]
# # Step 3: Find the dimensions (number of rows and columns) in the data frame. What do these two numbers represent in the context of the data?

# %%
#Total numbe of records 
df.shape
# Out:
# (16719, 16)

# %% [markdown]
# 16719 represent the rows and 16 is represent the number of columns in this data set.

# %% [markdown]
# # Step 4: Find the top five games by critic score.

# %%
# Get the top 5 games by critic score
df.sort_values(by = 'Critic_Score', axis = 0, ascending = False).head(5)
# Out:
#                           Name Platform  Year_of_Release     Genre  \
# 227   Tony Hawk's Pro Skater 2       PS           2000.0    Sports
# 57         Grand Theft Auto IV      PS3           2008.0    Action
# 51         Grand Theft Auto IV     X360           2008.0    Action
# 5350               SoulCalibur       DC           1999.0  Fighting
# 165         Grand Theft Auto V     XOne           2014.0    Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 227             Activision      3.05      1.41      0.02         0.20
# 57    Take-Two Interactive      4.76      3.69      0.44         1.61
# 51    Take-Two Interactive      6.76      3.07      0.14         1.03
# 5350    Namco Bandai Games      0.00      0.00      0.34         0.00
# 165   Take-Two Interactive      2.81      2.19      0.00         0.47
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %% [markdown]
# # Step 5: Find the number of video games in the data frame in each genre.

# %%
# Find the number of games in each 'Genre'
# Group by 'Genre' to find the number of games
df[['Genre']].groupby('Genre').count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Action, Adventure, Fighting, Misc, Platform, Puzzle, Racing, Role-Playing, Shooter, Simulation, Sports, Strategy]

# %% [markdown]
# # Step 6: Find the first five games in the data frame on the SNES platform.

# %%
# Get the first five games on the 'SNES'
df[df['Platform'] == 'SNES'].head(5)
# Out:
#                                      Name Platform  Year_of_Release     Genre  \
# 18                      Super Mario World     SNES           1990.0  Platform
# 56                  Super Mario All-Stars     SNES           1993.0  Platform
# 71                    Donkey Kong Country     SNES           1994.0  Platform
# 76                       Super Mario Kart     SNES           1992.0    Racing
# 137  Street Fighter II: The World Warrior     SNES           1992.0  Fighting
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 18   Nintendo     12.78      3.75      3.54         0.55         20.61
# 56   Nintendo      5.99      2.15      2.12         0.29         10.55
# 71   Nintendo      4.36      1.71      3.00         0.23          9.30
# 76   Nintendo      3.54      1.24      3.81         0.18          8.76
# 137    Capcom      2.47      0.83      2.87         0.12          6.30
#
# ...

# %% [markdown]
# # Step 7: Find the five publishers with the highest total global sales. Note: You will need to calculate the total global sales for each publisher to do this.

# %%
# Get top five publisher with the highest total global sales.
# Get sum of global sales for each publisher
df[['Publisher','Global_Sales']].groupby('Publisher').sum()\
.sort_values(by = 'Global_Sales', axis=0, ascending = False).head(5)
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1788.81
# Electronic Arts                   1116.96
# Activision                         731.16
# Sony Computer Entertainment        606.48
# Ubisoft                            471.61

# %% [markdown]
# # Step 8: Create a new column in the data frame that calculates the percentage of global sales from North America. Display the first five rows of the new data frame.

# %%
# Calculate percentage of global sales from North America
# Creat percentage column to reprecent percentage of global sales from North America
df['percentage'] = df['NA_Sales']/df['Global_Sales']*100
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# # Step 9: Find the number NaN entries (missing data values) in each column.

# %%
# Check for missing data
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# percentage            0
# dtype: int64

# %%
# Use isnull() to find all columns with NaN values:
df.isnull().any()
# Out:
# Name                True
# Platform           False
# Year_of_Release     True
# Genre               True
# Publisher           True
# NA_Sales           False
# EU_Sales           False
# JP_Sales           False
# Other_Sales        False
# Global_Sales       False
# Critic_Score        True
# Critic_Count        True
# User_Score          True
# User_Count          True
# Developer           True
# Rating              True
# percentage         False
# dtype: bool

# %% [markdown]
# # Step 10: Try to calculate the median user score of all the video games. You will likely run into an error because some of the user score entries are a non-numerical string that cannot be converted to a float. Find and replace this string with NaN and then calculate the median. Then, replace all NaN entries in the user score column with the median value.

# %%
# Use isna() to select all columns with NaN values:
df[df.columns[df.isna().any()]]
# Out:
#                                 Name  Year_of_Release         Genre  \
# 0                         Wii Sports           2006.0        Sports
# 1                  Super Mario Bros.           1985.0      Platform
# 2                     Mario Kart Wii           2008.0        Racing
# 3                  Wii Sports Resort           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue           1996.0  Role-Playing
# ...                              ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru           2016.0        Action
# 16715               LMA Manager 2007           2006.0        Sports
# 16716        Haitaka no Psychedelica           2016.0     Adventure
# 16717               Spirits & Spells           2003.0      Platform
# 16718            Winning Post 8 2016           2016.0    Simulation
#
#           Publisher  Critic_Score  Critic_Count User_Score  User_Count  \
# 0          Nintendo          76.0          51.0          8       322.0
# ...

# %%
# skip the Na values while finding the median
df.median(axis = 0, skipna = True)
# Out:
# C:\Users\Yousof\AppData\Local\Temp/ipykernel_6936/3221307487.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis = 0, skipna = True)
# Year_of_Release    2007.00
# NA_Sales              0.08
# EU_Sales              0.02
# JP_Sales              0.00
# Other_Sales           0.01
# Global_Sales          0.17
# Critic_Score         71.00
# Critic_Count         21.00
# User_Count           24.00
# percentage           50.00
# dtype: float64

# %%
#find median value in specific column
df1=df.replace("tbd", np.NaN)
df1
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Get the median user score
df1['User_Score'].median()
# Out:
# 7.5

# %%
# replace all NaN entries in the user score column with the median value
df1['User_Score'].fillna(df1['User_Score'].median())
# Out:
# 0          8
# 1        7.5
# 2        8.3
# 3          8
# 4        7.5
#         ...
# 16714    7.5
# 16715    7.5
# 16716    7.5
# 16717    7.5
# 16718    7.5
# Name: User_Score, Length: 16719, dtype: object

# %%
# Replace the actual column in the dataframe
df1['User_Score'].fillna(df1['User_Score'].median(), inplace = True)
df1
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...
